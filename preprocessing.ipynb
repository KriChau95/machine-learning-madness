# %%
import pandas as pd
import os

# %%
def col_list(csv_file):
    df = pd.read_csv(f'data/{csv_file}')
    return df.columns.tolist()

# %%
csv_list = os.listdir('data')
csv_list.remove(".gitattributes")
for i in range(len(csv_list)):
    csv = csv_list[i]
    print(f"{i + 1}: {csv} - Columns: {col_list(csv)}")
# Out:
# 1: MNCAATourneyDetailedResults.csv - Columns: ['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc', 'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR', 'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3', 'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF']
# 2: WNCAATourneySlots.csv - Columns: ['Season', 'Slot', 'StrongSeed', 'WeakSeed']
# 3: MNCAATourneyCompactResults.csv - Columns: ['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc', 'NumOT']
# 4: MSeasons.csv - Columns: ['Season', 'DayZero', 'RegionW', 'RegionX', 'RegionY', 'RegionZ']
# 5: WTeams.csv - Columns: ['TeamID', 'TeamName']
# 6: MRegularSeasonDetailedResults.csv - Columns: ['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc', 'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR', 'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3', 'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF']
# 7: WNCAATourneyDetailedResults.csv - Columns: ['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc', 'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR', 'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3', 'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF']
# 8: MNCAATourneySlots.csv - Columns: ['Season', 'Slot', 'StrongSeed', 'WeakSeed']
# 9: MConferenceTourneyGames.csv - Columns: ['Season', 'ConfAbbrev', 'DayNum', 'WTeamID', 'LTeamID']
# 10: WNCAATourneyCompactResults.csv - Columns: ['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc', 'NumOT']
# 11: WSeasons.csv - Columns: ['Season', 'DayZero', 'RegionW', 'RegionX', 'RegionY', 'RegionZ']
# 12: WRegularSeasonCompactResults.csv - Columns: ['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc', 'NumOT']
# 13: WRegularSeasonDetailedResults.csv - Columns: ['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc', 'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR', 'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3', 'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF']
# 14: MRegularSeasonCompactResults.csv - Columns: ['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc', 'NumOT']
# 15: WNCAATourneySeeds.csv - Columns: ['Season', 'Seed', 'TeamID']
# 16: MNCAATourneySeedRoundSlots.csv - Columns: ['Seed', 'GameRound', 'GameSlot', 'EarlyDayNum', 'LateDayNum']
# 17: WConferenceTourneyGames.csv - Columns: ['Season', 'ConfAbbrev', 'DayNum', 'WTeamID', 'LTeamID']
# 18: WTeamConferences.csv - Columns: ['Season', 'TeamID', 'ConfAbbrev']
# 19: MTeamConferences.csv - Columns: ['Season', 'TeamID', 'ConfAbbrev']
# 20: MTeamCoaches.csv - Columns: ['Season', 'TeamID', 'FirstDayNum', 'LastDayNum', 'CoachName']
# 21: MMasseyOrdinals.csv - Columns: ['Season', 'RankingDayNum', 'SystemName', 'TeamID', 'OrdinalRank']
# 22: MTeams.csv - Columns: ['TeamID', 'TeamName', 'FirstD1Season', 'LastD1Season']
# 23: MNCAATourneySeeds.csv - Columns: ['Season', 'Seed', 'TeamID']

# %%
mens_data = [csv for csv in csv_list if csv[0] == 'M']
womens_data = [csv for csv in csv_list if csv[0] == 'W']

print("MENS INFO:")

for mf in mens_data:
    print(f"{mf[:-4]}: {col_list(mf)}")

print("\nWOMENS INFO:")

for wf in womens_data:
    print(f"{wf[:-4]}: {col_list(wf)}")
# Out:
# MNCAATourneyDetailedResults: ['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc', 'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR', 'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3', 'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF']
# MNCAATourneyCompactResults: ['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc', 'NumOT']
# MSeasons: ['Season', 'DayZero', 'RegionW', 'RegionX', 'RegionY', 'RegionZ']
# MRegularSeasonDetailedResults: ['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc', 'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR', 'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3', 'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF']
# MNCAATourneySlots: ['Season', 'Slot', 'StrongSeed', 'WeakSeed']
# MConferenceTourneyGames: ['Season', 'ConfAbbrev', 'DayNum', 'WTeamID', 'LTeamID']
# MRegularSeasonCompactResults: ['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc', 'NumOT']
# MNCAATourneySeedRoundSlots: ['Seed', 'GameRound', 'GameSlot', 'EarlyDayNum', 'LateDayNum']
# MTeamConferences: ['Season', 'TeamID', 'ConfAbbrev']
# MTeamCoaches: ['Season', 'TeamID', 'FirstDayNum', 'LastDayNum', 'CoachName']
# MMasseyOrdinals: ['Season', 'RankingDayNum', 'SystemName', 'TeamID', 'OrdinalRank']
# MTeams: ['TeamID', 'TeamName', 'FirstD1Season', 'LastD1Season']
# MNCAATourneySeeds: ['Season', 'Seed', 'TeamID']
